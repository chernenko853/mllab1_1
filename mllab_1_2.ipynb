# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#считаем данные из файла

aircrashdb = pd.read_csv('Airplane.csv')
aircrashdb.head(10)
# Out:
#          Date   Time                            Location  \
# 0  09/17/1908  17:18                 Fort Myer, Virginia
# 1  09/07/1909    NaN             Juvisy-sur-Orge, France
# 2  07/12/1912  06:30           Atlantic City, New Jersey
# 3  08/06/1913    NaN  Victoria, British Columbia, Canada
# 4  09/09/1913  18:30                  Over the North Sea
# 5  10/17/1913  10:30          Near Johannisthal, Germany
# 6  03/05/1915  01:00                     Tienen, Belgium
# 7  09/03/1915  15:20               Off Cuxhaven, Germany
# 8  07/28/1916    NaN               Near Jambol, Bulgeria
# 9  09/24/1916  01:00                 Billericay, England
#
#                  Operator Flight #          Route  \
# 0    Military - U.S. Army      NaN  Demonstration
# 1                     NaN      NaN       Air show
# 2    Military - U.S. Navy      NaN    Test flight
# 3                 Private      NaN            NaN
# 4  Military - German Navy      NaN            NaN
# ...

# %%
aircrashdb.shape
# Out:
# (4967, 17)

# %%
aircrashdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4967 entries, 0 to 4966
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   4967 non-null   object
#  1   Time                   3457 non-null   object
#  2   Location               4963 non-null   object
#  3   Operator               4957 non-null   object
#  4   Flight #               1315 non-null   object
#  5   Route                  4193 non-null   object
#  6   AC Type                4952 non-null   object
#  7   Registration           4694 non-null   object
#  8   cn/ln                  4299 non-null   object
#  9   Aboard                 4949 non-null   float64
#  10  Aboard Passangers      4738 non-null   float64
#  11  Aboard Crew            4741 non-null   float64
#  12  Fatalities             4959 non-null   float64
#  13  Fatalities Passangers  4725 non-null   float64
# ...

# %%
#удаление строк дубликатов
aircrashdb = aircrashdb[~aircrashdb.duplicated()==1]
aircrashdb.shape
# Out:
# (4967, 17)

# %%
#гистограммы датасета
aircrashdb.hist(figsize = (12, 12), bins = 45)
plt.tight_layout()
plt.show()

# %%
numeric_columns = aircrashdb.columns[aircrashdb.dtypes != 'object']
string_columns = aircrashdb.columns[aircrashdb.dtypes == 'object']

print("Количество числовых колонок: {0}\nКоличество числовых колонок: {1}".format(len(numeric_columns), len(string_columns)))
# Out:
# Количество числовых колонок: 7
# Количество числовых колонок: 10

# %%
numeric_aircrashdb = pd.DataFrame(data = aircrashdb, columns = numeric_columns, index = pornushka.index)
corr = abs(numeric_aircrashdb.corr())
fig, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(corr, vmax=1, vmin=0, center=0,linewidth=.5, square=True, annot = True, annot_kws = {'size':8},fmt='.1f', cmap='RdBu_r')
plt.title('корреляция')
plt.show()

# %%
features = ['Ground', 'Aboard', 'Fatalities Crew']
features_aircrashdb = aircrashdb[features]

# %%
for feature in features:
    sns.scatterplot(x = feature, y = "Fatalities", data = aircrashdb, alpha=0.03, color='green')
    plt.pause(0.05)

plt.show()
